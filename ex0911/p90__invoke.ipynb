# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(
    temperature=0.1,
    model="gpt-4.1-nano"
)

# %%
# 질문요청
req = "대한민국 수도는 어디인가요?"
res = llm.invoke(req)

# %%
print(res)
# Out:
# content='대한민국의 수도는 서울입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 15, 'total_tokens': 23, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_1c77073857', 'id': 'chatcmpl-EMq64PiMCa7Qz3rHV0dtuByradQCz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a08f65-6b1f-7383-96a4-b5307ab6c30e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 8, 'total_tokens': 23, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
res.content
# Out:
# '대한민국의 수도는 서울입니다.'

# %%
res.additional_kwargs
# Out:
# {'refusal': None}

# %%
res.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 8,
#   'prompt_tokens': 15,
#   'total_tokens': 23,
#   'completion_tokens_details': {'accepted_prediction_tokens': 0,
#    'audio_tokens': 0,
#    'reasoning_tokens': 0,
#    'rejected_prediction_tokens': 0,
#    'text_tokens': None},
#   'prompt_tokens_details': {'audio_tokens': 0,
#    'cache_write_tokens': None,
#    'cached_tokens': 0,
#    'image_tokens': None,
#    'text_tokens': None}},
#  'model_provider': 'openai',
#  'model_name': 'gpt-4.1-nano-2025-04-14',
#  'system_fingerprint': 'fp_1c77073857',
#  'id': 'chatcmpl-EMq64PiMCa7Qz3rHV0dtuByradQCz',
#  'service_tier': 'default',
#  'finish_reason': 'stop',
#  'logprobs': None}
